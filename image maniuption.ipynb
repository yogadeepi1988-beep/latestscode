# %%
# !pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in .\venv_cv\Lib\site-packages (3.10.9)
# Requirement already satisfied: contourpy>=1.0.1 in .\venv_cv\Lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in .\venv_cv\Lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in .\venv_cv\Lib\site-packages (from matplotlib) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in .\venv_cv\Lib\site-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: numpy>=1.23 in .\venv_cv\Lib\site-packages (from matplotlib) (2.4.6)
# Requirement already satisfied: packaging>=20.0 in .\venv_cv\Lib\site-packages (from matplotlib) (26.2)
# Requirement already satisfied: pillow>=8 in .\venv_cv\Lib\site-packages (from matplotlib) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in .\venv_cv\Lib\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in .\venv_cv\Lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in .\venv_cv\Lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# WARNING: Cache entry deserialization failed, entry ignored
#
# [notice] A new release of pip is available: 26.1.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import cv2
import matplotlib.pyplot as plt

image = cv2.imread('example.jpg')

#convert BGR to RGB
image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
plt.imshow(image_rgb)
plt.title("RGB Image")
plt.show()

#covnert to grayscale
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
plt.imshow(gray_image, cmap='gray')
plt.title("Grayscale Image")
plt.show

#Cropping the image
#Assume we know the region we want: rows 100 to 300, columns 200 to 400
cropped_image = image[100:200, 100:200]
cropped_rgb = cv2.cvtColor(cropped_image, cv2.COLOR_BGR2RGB)
plt.imshow(cropped_rgb)
plt.title("Cropped Reigon")
plt.show()
